# %% [markdown]
# # Notebook 2 - Dataset Cresci 2017 - Teste 2

# %% [markdown]
# Link do Dataset: https://botometer.osome.iu.edu/bot-repository/datasets.html

# %% [markdown]
# ## Objetivos

# %% [markdown]
# Encontrar métricas eficientes para avaliar se uma conta é um bot simples(apenas para gerar seguidores).
#
# Avaliar o desempenho de diferentes algoritmos para os mesmos dados.

# %% [markdown]
# ## Composição dos Dados de Treino/Teste

# %% [markdown]
# Nesse teste, utilizaremos os dados dos seguintes datasets: traditional spambots 1, 2, 3, 4 e genuine_accounts.
# O dataframe usado para o treino de diversos modelos de machine learning é composto de 50% de contas bots(traditional_spambots) e 50% de contas legítimas(genuine_accounts).
# Os dados que serão usados para teste seguem exatamente a mesma composição explicada anteriormente.
#
# Relativo ao dataset de treino, ele utiliza 75% dos dados do dataset traditional_spambots, já o dataset de teste é composto por 25%.
# A proporção se mantém a igual para os dados referentes as contas genuínas.

# %% [markdown]
# # Escolha das features

# %% [markdown]
# A escolha dos dados relevantes foi feita considerando 3 grandes fatores:
#
# 1 - A disponibilidade de tais informações na versão atual da API oficial do Twitter.
#
# 2 - Os artigos: Supervised Machine Learning Bot Detection Techniques to Identify Social Twitter Bots e The Paradigm-Shift of Social Spambots: Evidence, Theories, and Tools for the Arms Race que revisam o estado da arte na identificação de perfis bot.
#
# 3 - Minhas hipoteses que serão explicadas posteriormente.

# %% [markdown]
# ### Libs que serão utilizadas para a realização dos testes:

# %% [markdown]
# Para fazer a visualização da árvore de decisão é necessário instalar a lib graphviz para isso use o comando acima. Além disso, instale o graphviz em seu sistema operacional

# %%
import pandas as pd
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.svm import LinearSVC 
from sklearn.metrics import accuracy_score
from sklearn.dummy import DummyClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
import graphviz
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %% [markdown]
# Para melhorar a visualização dos dataframes:

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# Nesse trecho do código fazemos a leitura do arquivo de usuários da base de dados de traditional_spambots. E em seguida mostramos a dimensão dos dados obtidos, sendo 3351 linhas(registros) e 38 colunas(features).

# %%
tradional_spam_bots_1 = pd.read_csv("../datasets/traditional_spambots_1/users.csv")
tradional_spam_bots_1.shape
# Out:
# (1000, 40)

# %%
tradional_spam_bots_1.head()
# Out:
#          id           name      screen_name  statuses_count  followers_count  \
# 0   7248952   Bhuvan Chand      tarunkjuyal            1259              837
# 1   7732472  Daniel Wagner     DanielWagner             770             3274
# 2   9524952    Andrew Lock       Andrewlock            1100            38849
# 3  10788822   Tim Thompson  yourinsaneworld            6497             5902
# 4  14596967        fxgenie          fxgenie            3203             2570
#
#    friends_count  favourites_count  listed_count  \
# 0           1978              3200             9
# 1           3595                 8            22
# 2          34504                41          1014
# 3           5496                 0            82
# 4           2638                 0             5
#
#                                      url  lang  time_zone      location  \
# 0                 http://lifeofearth.org   NaN        NaN      Berekely
# 1  http://www.yourinternetbuddies.com/go   NaN        NaN            UK
# 2          http://www.helpmybusiness.com   NaN        NaN  Planet Earth
# 3       http://investing-information.com   NaN        NaN   Houston, TX
# 4              http://www.4xgenie.com/wp   NaN        NaN           usa
#
#    default_profile  default_profile_image  geo_enabled  \
# 0              NaN                    NaN          NaN
# 1              NaN                    NaN          NaN
# 2              NaN                    NaN          NaN
# 3              NaN                    NaN          NaN
# 4              NaN                    NaN          NaN
#
#                                    profile_image_url  profile_banner_url  \
# 0  http://a1.twimg.com/profile_images/53905961/st...                 NaN
# 1  http://a3.twimg.com/profile_images/719249843/d...                 NaN
# 2  http://a3.twimg.com/profile_images/516987291/b...                 NaN
# 3  http://a3.twimg.com/profile_images/200984855/t...                 NaN
# 4  http://a2.twimg.com/profile_images/53530606/sh...                 NaN
#
#    profile_use_background_image  profile_background_image_url_https  \
# 0                           NaN                                 NaN
# 1                           NaN                                 NaN
# 2                           NaN                                 NaN
# 3                           NaN                                 NaN
# 4                           NaN                                 NaN
#
#    profile_text_color  profile_image_url_https  profile_sidebar_border_color  \
# 0                 NaN                      NaN                           NaN
# 1                 NaN                      NaN                           NaN
# 2                 NaN                      NaN                           NaN
# 3                 NaN                      NaN                           NaN
# 4                 NaN                      NaN                           NaN
#
#    profile_background_tile  profile_sidebar_fill_color  \
# 0                      NaN                         NaN
# 1                      NaN                         NaN
# 2                      NaN                         NaN
# 3                      NaN                         NaN
# 4                      NaN                         NaN
#
#                         profile_background_image_url  \
# 0  http://s.twimg.com/a/1288374569/images/themes/...
# 1  http://a3.twimg.com/profile_background_images/...
# 2  http://s.twimg.com/a/1288305442/images/themes/...
# 3  http://s.twimg.com/a/1288039940/images/themes/...
# 4  http://a1.twimg.com/profile_background_images/...
#
#    profile_background_color  profile_link_color  utc_offset  is_translator  \
# 0                       NaN                 NaN         NaN            NaN
# 1                       NaN                 NaN         NaN            NaN
# 2                       NaN                 NaN         NaN            NaN
# 3                       NaN                 NaN         NaN            NaN
# 4                       NaN                 NaN         NaN            NaN
#
#    follow_request_sent  protected  verified  notifications  \
# 0                  NaN        NaN       NaN            NaN
# 1                  NaN        NaN       NaN            NaN
# 2                  NaN        NaN       NaN            NaN
# 3                  NaN        NaN       NaN            NaN
# 4                  NaN        NaN       NaN            NaN
#
#                                          description  contributors_enabled  \
# 0                                     Love Your Life                   NaN
# 1  I am an internet marketing coach and mentor wh...                   NaN
# 2  Marketing Geek & Presenter of 'Help! My Busine...                   NaN
# 3  I am a member of a network of stock investing ...                   NaN
# 4                                       forex trader                   NaN
#
#    following      created_at            timestamp           crawled_at  \
# 0        NaN  1183552203000L  2007-07-04 14:30:03  2010-11-07 11:10:52
# 1        NaN  1185440851000L  2007-07-26 11:07:31  2010-11-07 11:10:52
# 2        NaN  1192725360000L  2007-10-18 18:36:00  2010-11-07 11:10:52
# 3        NaN  1196614406000L  2007-12-02 17:53:26  2010-11-07 11:10:52
# 4        NaN  1209536534000L  2008-04-30 08:22:14  2010-11-07 11:10:52
#
#                updated
# 0  2016-03-14 17:05:53
# 1  2016-03-14 17:05:54
# 2  2016-03-14 17:05:54
# 3  2016-03-14 17:05:54
# 4  2016-03-14 17:05:54

# %%
tradional_spam_bots_2 = pd.read_csv("../datasets/traditional_spambots_2/users.csv")
tradional_spam_bots_2.shape
# Out:
# (100, 40)

# %%
tradional_spam_bots_2.head()
# Out:
#            id             name      screen_name  statuses_count  \
# 0  2355955040  Prize Giveaways  PrizeCrazy66450             716
# 1  2368624550  Prize Giveaways  Prizetopia43484             779
# 2  2355950858      Prize Crazy    TweetWin57918             753
# 3  2357744766      Prize World  Prizetopia67432             743
# 4  2362454995     Prize Rocket    PrizeFun52329             180
#
#    followers_count  friends_count  favourites_count  listed_count  \
# 0               86             78                 0             4
# 1               87             79                 0             2
# 2               89             97                 0             0
# 3               93            104                 0             4
# 4               87             71                 0             1
#
#                       url   lang time_zone location  default_profile  \
# 0  http://t.co/CF0tmHKIHk  en-gb    Hawaii      NaN              NaN
# 1  http://t.co/3agfNy4i4S  en-gb    Hawaii      NaN              NaN
# 2  http://t.co/jlIaA4LovD  en-gb    Hawaii      NaN              NaN
# 3  http://t.co/lVWwVDdjr6  en-gb    Hawaii      NaN              NaN
# 4  http://t.co/rPMDkKvchA  en-gb    Hawaii      NaN              NaN
#
#    default_profile_image  geo_enabled  \
# 0                    NaN          NaN
# 1                    NaN          NaN
# 2                    NaN          NaN
# 3                    NaN          NaN
# 4                    NaN          NaN
#
#                                    profile_image_url  \
# 0  http://pbs.twimg.com/profile_images/4573684042...
# 1  http://pbs.twimg.com/profile_images/4570426000...
# 2  http://pbs.twimg.com/profile_images/4573683397...
# 3  http://pbs.twimg.com/profile_images/4570509940...
# 4  http://pbs.twimg.com/profile_images/4619790772...
#
#                                   profile_banner_url  \
# 0  https://pbs.twimg.com/profile_banners/23559550...
# 1  https://pbs.twimg.com/profile_banners/23686245...
# 2  https://pbs.twimg.com/profile_banners/23559508...
# 3  https://pbs.twimg.com/profile_banners/23577447...
# 4  https://pbs.twimg.com/profile_banners/23624549...
#
#    profile_use_background_image  \
# 0                             1
# 1                             1
# 2                             1
# 3                             1
# 4                             1
#
#                   profile_background_image_url_https  profile_text_color  \
# 0  https://pbs.twimg.com/profile_background_image...              333333
# 1  https://pbs.twimg.com/profile_background_image...              333333
# 2  https://pbs.twimg.com/profile_background_image...              333333
# 3  https://pbs.twimg.com/profile_background_image...              333333
# 4  https://pbs.twimg.com/profile_background_image...              333333
#
#                              profile_image_url_https  \
# 0  https://pbs.twimg.com/profile_images/457368404...
# 1  https://pbs.twimg.com/profile_images/457042600...
# 2  https://pbs.twimg.com/profile_images/457368339...
# 3  https://pbs.twimg.com/profile_images/457050994...
# 4  https://pbs.twimg.com/profile_images/461979077...
#
#   profile_sidebar_border_color  profile_background_tile  \
# 0                       FFFFFF                      NaN
# 1                       FFFFFF                      NaN
# 2                       FFFFFF                      NaN
# 3                       FFFFFF                      NaN
# 4                       FFFFFF                      NaN
#
#   profile_sidebar_fill_color  \
# 0                     DDEEF6
# 1                     DDEEF6
# 2                     DDEEF6
# 3                     DDEEF6
# 4                     DDEEF6
#
#                         profile_background_image_url profile_background_color  \
# 0  http://pbs.twimg.com/profile_background_images...                   FFFFFF
# 1  http://pbs.twimg.com/profile_background_images...                   FFFFFF
# 2  http://pbs.twimg.com/profile_background_images...                   FFFFFF
# 3  http://pbs.twimg.com/profile_background_images...                   FFFFFF
# 4  http://pbs.twimg.com/profile_background_images...                   FFFFFF
#
#    profile_link_color  utc_offset  is_translator  follow_request_sent  \
# 0       7.000000e+306      -36000            NaN                  NaN
# 1       7.000000e+306      -36000            NaN                  NaN
# 2       7.000000e+306      -36000            NaN                  NaN
# 3       7.000000e+306      -36000            NaN                  NaN
# 4       7.000000e+306      -36000            NaN                  NaN
#
#    protected  verified  notifications  \
# 0        NaN       NaN            NaN
# 1        NaN       NaN            NaN
# 2        NaN       NaN            NaN
# 3        NaN       NaN            NaN
# 4        NaN       NaN            NaN
#
#                                          description  contributors_enabled  \
# 0  NOTICE TO WINNERS: A unique prize code is nece...                   NaN
# 1  NOTICE TO WINNERS: A unique invite code is nee...                   NaN
# 2  NOTICE TO WINNERS: A unique invitation code is...                   NaN
# 3  NOTICE TO WINNERS: A unique invitation code is...                   NaN
# 4  NOTE TO WINNERS: A unique invitation code is n...                   NaN
#
#    following                      created_at            timestamp  \
# 0        NaN  Sat Feb 22 07:22:34 +0000 2014  2014-02-22 08:22:34
# 1        NaN  Sun Mar 02 09:38:19 +0000 2014  2014-03-02 10:38:19
# 2        NaN  Sat Feb 22 07:19:00 +0000 2014  2014-02-22 08:19:00
# 3        NaN  Sun Feb 23 09:30:43 +0000 2014  2014-02-23 10:30:43
# 4        NaN  Wed Feb 26 09:57:57 +0000 2014  2014-02-26 10:57:57
#
#             crawled_at              updated
# 0  2014-05-05 21:59:19  2016-03-14 15:46:02
# 1  2014-05-05 21:59:19  2016-03-14 15:46:02
# 2  2014-05-05 21:59:19  2016-03-14 15:46:02
# 3  2014-05-05 21:59:19  2016-03-14 15:46:03
# 4  2014-05-05 21:59:19  2016-03-14 15:46:03

# %%
tradional_spam_bots_3 = pd.read_csv("../datasets/traditional_spambots_3/users.csv")
tradional_spam_bots_3.shape
# Out:
# (403, 40)

# %%
tradional_spam_bots_4= pd.read_csv("../datasets/traditional_spambots_4/users.csv")
tradional_spam_bots_4.shape
# Out:
# (1128, 40)

# %%
print(tradional_spam_bots_1.keys().all() == tradional_spam_bots_2.keys().all() 
      and tradional_spam_bots_2.keys().all() == tradional_spam_bots_3.keys().all() 
      and tradional_spam_bots_3.keys().all() == tradional_spam_bots_4.keys().all())
# Out:
# True

# %%
traditional_spambots = pd.concat([tradional_spam_bots_1, tradional_spam_bots_2,tradional_spam_bots_3,tradional_spam_bots_4], ignore_index= True)
traditional_spambots.shape
# Out:
# (2631, 40)

# %%
traditional_spambots.head()
# Out:
#          id           name      screen_name  statuses_count  followers_count  \
# 0   7248952   Bhuvan Chand      tarunkjuyal            1259              837
# 1   7732472  Daniel Wagner     DanielWagner             770             3274
# 2   9524952    Andrew Lock       Andrewlock            1100            38849
# 3  10788822   Tim Thompson  yourinsaneworld            6497             5902
# 4  14596967        fxgenie          fxgenie            3203             2570
#
#    friends_count  favourites_count  listed_count  \
# 0           1978              3200             9
# 1           3595                 8            22
# 2          34504                41          1014
# 3           5496                 0            82
# 4           2638                 0             5
#
#                                      url lang time_zone      location  \
# 0                 http://lifeofearth.org  NaN       NaN      Berekely
# 1  http://www.yourinternetbuddies.com/go  NaN       NaN            UK
# 2          http://www.helpmybusiness.com  NaN       NaN  Planet Earth
# 3       http://investing-information.com  NaN       NaN   Houston, TX
# 4              http://www.4xgenie.com/wp  NaN       NaN           usa
#
#    default_profile  default_profile_image  geo_enabled  \
# 0              NaN                    NaN          NaN
# 1              NaN                    NaN          NaN
# 2              NaN                    NaN          NaN
# 3              NaN                    NaN          NaN
# 4              NaN                    NaN          NaN
#
#                                    profile_image_url profile_banner_url  \
# 0  http://a1.twimg.com/profile_images/53905961/st...                NaN
# 1  http://a3.twimg.com/profile_images/719249843/d...                NaN
# 2  http://a3.twimg.com/profile_images/516987291/b...                NaN
# 3  http://a3.twimg.com/profile_images/200984855/t...                NaN
# 4  http://a2.twimg.com/profile_images/53530606/sh...                NaN
#
#    profile_use_background_image profile_background_image_url_https  \
# 0                           NaN                                NaN
# 1                           NaN                                NaN
# 2                           NaN                                NaN
# 3                           NaN                                NaN
# 4                           NaN                                NaN
#
#   profile_text_color profile_image_url_https profile_sidebar_border_color  \
# 0                NaN                     NaN                          NaN
# 1                NaN                     NaN                          NaN
# 2                NaN                     NaN                          NaN
# 3                NaN                     NaN                          NaN
# 4                NaN                     NaN                          NaN
#
#    profile_background_tile profile_sidebar_fill_color  \
# 0                      NaN                        NaN
# 1                      NaN                        NaN
# 2                      NaN                        NaN
# 3                      NaN                        NaN
# 4                      NaN                        NaN
#
#                         profile_background_image_url profile_background_color  \
# 0  http://s.twimg.com/a/1288374569/images/themes/...                      NaN
# 1  http://a3.twimg.com/profile_background_images/...                      NaN
# 2  http://s.twimg.com/a/1288305442/images/themes/...                      NaN
# 3  http://s.twimg.com/a/1288039940/images/themes/...                      NaN
# 4  http://a1.twimg.com/profile_background_images/...                      NaN
#
#   profile_link_color  utc_offset  is_translator  follow_request_sent  \
# 0                NaN         NaN            NaN                  NaN
# 1                NaN         NaN            NaN                  NaN
# 2                NaN         NaN            NaN                  NaN
# 3                NaN         NaN            NaN                  NaN
# 4                NaN         NaN            NaN                  NaN
#
#    protected  verified  notifications  \
# 0        NaN       NaN            NaN
# 1        NaN       NaN            NaN
# 2        NaN       NaN            NaN
# 3        NaN       NaN            NaN
# 4        NaN       NaN            NaN
#
#                                          description  contributors_enabled  \
# 0                                     Love Your Life                   NaN
# 1  I am an internet marketing coach and mentor wh...                   NaN
# 2  Marketing Geek & Presenter of 'Help! My Busine...                   NaN
# 3  I am a member of a network of stock investing ...                   NaN
# 4                                       forex trader                   NaN
#
#    following      created_at            timestamp           crawled_at  \
# 0        NaN  1183552203000L  2007-07-04 14:30:03  2010-11-07 11:10:52
# 1        NaN  1185440851000L  2007-07-26 11:07:31  2010-11-07 11:10:52
# 2        NaN  1192725360000L  2007-10-18 18:36:00  2010-11-07 11:10:52
# 3        NaN  1196614406000L  2007-12-02 17:53:26  2010-11-07 11:10:52
# 4        NaN  1209536534000L  2008-04-30 08:22:14  2010-11-07 11:10:52
#
#                updated
# 0  2016-03-14 17:05:53
# 1  2016-03-14 17:05:54
# 2  2016-03-14 17:05:54
# 3  2016-03-14 17:05:54
# 4  2016-03-14 17:05:54

# %% [markdown]
# Como todos os perfis dessa base de dados são perfis bot, criaremos uma coluna adicional no dataframe sinalizando tal fato para que possamos diferenciar os diferentes tipos de pefil posteriormente.

# %%
traditional_spambots['is_bot'] = 1

# %% [markdown]
# Faremos o mesmo para o arquivo de perfis verdadeiros. Porém, dessa vez, sinalizaremos os perfis como 0.

# %%
real_accounts = pd.read_csv("../datasets/genuine_accounts/users.csv")
real_accounts.shape
# Out:
# (3474, 42)

# %%
real_accounts['is_bot'] = 0

# %% [markdown]
# Em seguida, analisaremos alguns dos dados obtidos a fim de avaliar o que utilizaremos para fazer a predição se um perfil é bot ou não.

# %%
traditional_spambots.head()
# Out:
#          id           name      screen_name  statuses_count  followers_count  \
# 0   7248952   Bhuvan Chand      tarunkjuyal            1259              837
# 1   7732472  Daniel Wagner     DanielWagner             770             3274
# 2   9524952    Andrew Lock       Andrewlock            1100            38849
# 3  10788822   Tim Thompson  yourinsaneworld            6497             5902
# 4  14596967        fxgenie          fxgenie            3203             2570
#
#    friends_count  favourites_count  listed_count  \
# 0           1978              3200             9
# 1           3595                 8            22
# 2          34504                41          1014
# 3           5496                 0            82
# 4           2638                 0             5
#
#                                      url lang time_zone      location  \
# 0                 http://lifeofearth.org  NaN       NaN      Berekely
# 1  http://www.yourinternetbuddies.com/go  NaN       NaN            UK
# 2          http://www.helpmybusiness.com  NaN       NaN  Planet Earth
# 3       http://investing-information.com  NaN       NaN   Houston, TX
# 4              http://www.4xgenie.com/wp  NaN       NaN           usa
#
#    default_profile  default_profile_image  geo_enabled  \
# 0              NaN                    NaN          NaN
# 1              NaN                    NaN          NaN
# 2              NaN                    NaN          NaN
# 3              NaN                    NaN          NaN
# 4              NaN                    NaN          NaN
#
#                                    profile_image_url profile_banner_url  \
# 0  http://a1.twimg.com/profile_images/53905961/st...                NaN
# 1  http://a3.twimg.com/profile_images/719249843/d...                NaN
# 2  http://a3.twimg.com/profile_images/516987291/b...                NaN
# 3  http://a3.twimg.com/profile_images/200984855/t...                NaN
# 4  http://a2.twimg.com/profile_images/53530606/sh...                NaN
#
#    profile_use_background_image profile_background_image_url_https  \
# 0                           NaN                                NaN
# 1                           NaN                                NaN
# 2                           NaN                                NaN
# 3                           NaN                                NaN
# 4                           NaN                                NaN
#
#   profile_text_color profile_image_url_https profile_sidebar_border_color  \
# 0                NaN                     NaN                          NaN
# 1                NaN                     NaN                          NaN
# 2                NaN                     NaN                          NaN
# 3                NaN                     NaN                          NaN
# 4                NaN                     NaN                          NaN
#
#    profile_background_tile profile_sidebar_fill_color  \
# 0                      NaN                        NaN
# 1                      NaN                        NaN
# 2                      NaN                        NaN
# 3                      NaN                        NaN
# 4                      NaN                        NaN
#
#                         profile_background_image_url profile_background_color  \
# 0  http://s.twimg.com/a/1288374569/images/themes/...                      NaN
# 1  http://a3.twimg.com/profile_background_images/...                      NaN
# 2  http://s.twimg.com/a/1288305442/images/themes/...                      NaN
# 3  http://s.twimg.com/a/1288039940/images/themes/...                      NaN
# 4  http://a1.twimg.com/profile_background_images/...                      NaN
#
#   profile_link_color  utc_offset  is_translator  follow_request_sent  \
# 0                NaN         NaN            NaN                  NaN
# 1                NaN         NaN            NaN                  NaN
# 2                NaN         NaN            NaN                  NaN
# 3                NaN         NaN            NaN                  NaN
# 4                NaN         NaN            NaN                  NaN
#
#    protected  verified  notifications  \
# 0        NaN       NaN            NaN
# 1        NaN       NaN            NaN
# 2        NaN       NaN            NaN
# 3        NaN       NaN            NaN
# 4        NaN       NaN            NaN
#
#                                          description  contributors_enabled  \
# 0                                     Love Your Life                   NaN
# 1  I am an internet marketing coach and mentor wh...                   NaN
# 2  Marketing Geek & Presenter of 'Help! My Busine...                   NaN
# 3  I am a member of a network of stock investing ...                   NaN
# 4                                       forex trader                   NaN
#
#    following      created_at            timestamp           crawled_at  \
# 0        NaN  1183552203000L  2007-07-04 14:30:03  2010-11-07 11:10:52
# 1        NaN  1185440851000L  2007-07-26 11:07:31  2010-11-07 11:10:52
# 2        NaN  1192725360000L  2007-10-18 18:36:00  2010-11-07 11:10:52
# 3        NaN  1196614406000L  2007-12-02 17:53:26  2010-11-07 11:10:52
# 4        NaN  1209536534000L  2008-04-30 08:22:14  2010-11-07 11:10:52
#
#                updated  is_bot
# 0  2016-03-14 17:05:53       1
# 1  2016-03-14 17:05:54       1
# 2  2016-03-14 17:05:54       1
# 3  2016-03-14 17:05:54       1
# 4  2016-03-14 17:05:54       1

# %%
real_accounts.head()
# Out:
#            id               name      screen_name  statuses_count  \
# 0  1502026416    TASUKU HAYAKAWA         0918Bask            2177
# 1  2492782375              ro_or         1120Roll            2660
# 2   293212315           bearclaw        14KBBrown            1254
# 3   191839658  pocahontas farida      wadespeters          202968
# 4  3020965143           Ms Kathy  191a5bd05da04dc              82
#
#    followers_count  friends_count  favourites_count  listed_count  \
# 0              208            332               265             1
# 1              330            485              3972             5
# 2              166            177              1185             0
# 3             2248            981             60304           101
# 4               21             79                 5             0
#
#                       url lang                   time_zone  \
# 0                     NaN   ja                         NaN
# 1                     NaN   ja                       Tokyo
# 2                     NaN   en  Eastern Time (US & Canada)
# 3  http://t.co/rGV0HIJGsu   en                   Greenland
# 4                     NaN   en                         NaN
#
#                     location  default_profile  default_profile_image  \
# 0             Tokyo .Japan .              NaN                    NaN
# 1                    神奈川県横浜市              1.0                    NaN
# 2                        NaN              NaN                    NaN
# 3  #freePalestine - rip paul              NaN                    NaN
# 4                 Wichita KS              1.0                    NaN
#
#    geo_enabled                                  profile_image_url  \
# 0          1.0  http://pbs.twimg.com/profile_images/5887331863...
# 1          1.0  http://pbs.twimg.com/profile_images/5737442928...
# 2          NaN  http://pbs.twimg.com/profile_images/5908597242...
# 3          1.0  http://pbs.twimg.com/profile_images/5915979249...
# 4          NaN  http://pbs.twimg.com/profile_images/5635511026...
#
#                                   profile_banner_url  \
# 0  https://pbs.twimg.com/profile_banners/15020264...
# 1  https://pbs.twimg.com/profile_banners/24927823...
# 2  https://pbs.twimg.com/profile_banners/29321231...
# 3  https://pbs.twimg.com/profile_banners/19183965...
# 4                                                NaN
#
#    profile_use_background_image  \
# 0                           NaN
# 1                           1.0
# 2                           1.0
# 3                           1.0
# 4                           1.0
#
#                   profile_background_image_url_https profile_text_color  \
# 0  https://abs.twimg.com/images/themes/theme1/bg.png             000000
# 1  https://abs.twimg.com/images/themes/theme1/bg.png             333333
# 2  https://pbs.twimg.com/profile_background_image...             0F9A89
# 3  https://abs.twimg.com/images/themes/theme3/bg.gif             634047
# 4  https://abs.twimg.com/images/themes/theme1/bg.png             333333
#
#                              profile_image_url_https  \
# 0  https://pbs.twimg.com/profile_images/588733186...
# 1  https://pbs.twimg.com/profile_images/573744292...
# 2  https://pbs.twimg.com/profile_images/590859724...
# 3  https://pbs.twimg.com/profile_images/591597924...
# 4  https://pbs.twimg.com/profile_images/563551102...
#
#   profile_sidebar_border_color  profile_background_tile  \
# 0                       000000                      NaN
# 1                       C0DEED                      NaN
# 2                       EED96D                      1.0
# 3                       D3D2CF                      NaN
# 4                       C0DEED                      NaN
#
#   profile_sidebar_fill_color  \
# 0                     000000
# 1                     DDEEF6
# 2                     EED96D
# 3                     E3E2DE
# 4                     DDEEF6
#
#                         profile_background_image_url profile_background_color  \
# 0   http://abs.twimg.com/images/themes/theme1/bg.png                   000000
# 1   http://abs.twimg.com/images/themes/theme1/bg.png                   C0DEED
# 2  http://pbs.twimg.com/profile_background_images...                   E63A50
# 3   http://abs.twimg.com/images/themes/theme3/bg.gif                   EDECE9
# 4   http://abs.twimg.com/images/themes/theme1/bg.png                   C0DEED
#
#   profile_link_color  utc_offset  is_translator  follow_request_sent  \
# 0             EB0C1F         NaN            NaN                  NaN
# 1             0084B4     32400.0            NaN                  NaN
# 2             E63A50    -14400.0            NaN                  NaN
# 3             088253     -7200.0            NaN                  NaN
# 4             0084B4         NaN            NaN                  NaN
#
#    protected  verified  notifications  \
# 0        NaN       NaN            NaN
# 1        NaN       NaN            NaN
# 2        NaN       NaN            NaN
# 3        NaN       NaN            NaN
# 4        NaN       NaN            NaN
#
#                                          description  contributors_enabled  \
# 0                              15years ago X.Lines24                   NaN
# 1   保守見習い地元大好き人間。 経済学、電工、仏教を勉強中、ちなDeではいかんのか？ (*^◯^*)                   NaN
# 2                 Let me see what your best move is!                   NaN
# 3  20. menna: #farida #nyc and the 80s actually y...                   NaN
# 4                                      Cosmetologist                   NaN
#
#    following                      created_at            timestamp  \
# 0        NaN  Tue Jun 11 11:20:35 +0000 2013  2013-06-11 13:20:35
# 1        NaN  Tue May 13 10:37:57 +0000 2014  2014-05-13 12:37:57
# 2        NaN  Wed May 04 23:30:37 +0000 2011  2011-05-05 01:30:37
# 3        NaN  Fri Sep 17 14:02:10 +0000 2010  2010-09-17 16:02:10
# 4        NaN  Fri Feb 06 04:10:49 +0000 2015  2015-02-06 05:10:49
#
#             crawled_at              updated  test_set_1  test_set_2  is_bot
# 0  2015-05-02 06:41:46  2016-03-15 15:53:47           0           0       0
# 1  2015-05-01 17:20:27  2016-03-15 15:53:48           0           0       0
# 2  2015-05-01 18:48:28  2016-03-15 15:53:48           0           0       0
# 3  2015-05-01 13:55:16  2016-03-15 15:53:48           0           0       0
# 4  2015-05-02 01:17:32  2016-03-15 15:53:48           0           0       0

# %%
traditional_spambots.describe()
# Out:
#                  id  statuses_count  followers_count  friends_count  \
# count  2.631000e+03     2631.000000     2.631000e+03    2631.000000
# mean   4.834289e+08     2365.651083     1.737488e+03     809.709996
# std    9.720966e+08     9902.642794     5.883970e+04    5116.089565
# min    7.248952e+06        0.000000     0.000000e+00       0.000000
# 25%    4.168144e+07        3.000000     9.300000e+01     246.000000
# 50%    7.085288e+07       32.000000     2.790000e+02     383.000000
# 75%    1.050727e+08      225.500000     5.315000e+02     686.500000
# max    4.331280e+09   153689.000000     2.991573e+06  211890.000000
#
#        favourites_count  listed_count  default_profile  default_profile_image  \
# count       2631.000000   2631.000000            107.0                   12.0
# mean           7.971114     31.072216              1.0                    1.0
# std          244.428583    594.861760              0.0                    0.0
# min            0.000000      0.000000              1.0                    1.0
# 25%            0.000000      1.000000              1.0                    1.0
# 50%            0.000000      4.000000              1.0                    1.0
# 75%            0.000000     15.000000              1.0                    1.0
# max        11962.000000  24348.000000              1.0                    1.0
#
#        geo_enabled  profile_use_background_image  profile_background_tile  \
# count       1106.0                        1513.0                     80.0
# mean           1.0                           1.0                      1.0
# std            0.0                           0.0                      0.0
# min            1.0                           1.0                      1.0
# 25%            1.0                           1.0                      1.0
# 50%            1.0                           1.0                      1.0
# 75%            1.0                           1.0                      1.0
# max            1.0                           1.0                      1.0
#
#          utc_offset  is_translator  follow_request_sent  protected  verified  \
# count   1320.000000            0.0                  0.0        0.0       0.0
# mean  -17498.181818            NaN                  NaN        NaN       NaN
# std     7087.457321            NaN                  NaN        NaN       NaN
# min   -39600.000000            NaN                  NaN        NaN       NaN
# 25%   -18000.000000            NaN                  NaN        NaN       NaN
# 50%   -14400.000000            NaN                  NaN        NaN       NaN
# 75%   -14400.000000            NaN                  NaN        NaN       NaN
# max    21600.000000            NaN                  NaN        NaN       NaN
#
#        notifications  contributors_enabled  following  is_bot
# count            0.0                   0.0        0.0  2631.0
# mean             NaN                   NaN        NaN     1.0
# std              NaN                   NaN        NaN     0.0
# min              NaN                   NaN        NaN     1.0
# 25%              NaN                   NaN        NaN     1.0
# 50%              NaN                   NaN        NaN     1.0
# 75%              NaN                   NaN        NaN     1.0
# max              NaN                   NaN        NaN     1.0

# %%
traditional_spambots.dtypes
# Out:
# id                                      int64
# name                                   object
# screen_name                            object
# statuses_count                          int64
# followers_count                         int64
# friends_count                           int64
# favourites_count                        int64
# listed_count                            int64
# url                                    object
# lang                                   object
# time_zone                              object
# location                               object
# default_profile                       float64
# default_profile_image                 float64
# geo_enabled                           float64
# profile_image_url                      object
# profile_banner_url                     object
# profile_use_background_image          float64
# profile_background_image_url_https     object
# profile_text_color                     object
# profile_image_url_https                object
# profile_sidebar_border_color           object
# profile_background_tile               float64
# profile_sidebar_fill_color             object
# profile_background_image_url           object
# profile_background_color               object
# profile_link_color                     object
# utc_offset                            float64
# is_translator                         float64
# follow_request_sent                   float64
# protected                             float64
# verified                              float64
# notifications                         float64
# description                            object
# contributors_enabled                  float64
# following                             float64
# created_at                             object
# timestamp                              object
# crawled_at                             object
# updated                                object
# is_bot                                  int64
# dtype: object

# %%
del traditional_spambots['is_translator']
del traditional_spambots['follow_request_sent']
del traditional_spambots['protected']
del traditional_spambots['contributors_enabled']
del traditional_spambots['following']
del traditional_spambots['notifications']
del traditional_spambots['profile_link_color']
del traditional_spambots['profile_background_color']
del traditional_spambots['profile_sidebar_fill_color']
del traditional_spambots['profile_sidebar_border_color']
del traditional_spambots['profile_text_color']
del traditional_spambots['profile_background_tile']
del traditional_spambots['updated']
del traditional_spambots['utc_offset']
del traditional_spambots['lang']
del traditional_spambots['time_zone']
del traditional_spambots['created_at']

# %%
traditional_spambots.head()
# Out:
#          id           name      screen_name  statuses_count  followers_count  \
# 0   7248952   Bhuvan Chand      tarunkjuyal            1259              837
# 1   7732472  Daniel Wagner     DanielWagner             770             3274
# 2   9524952    Andrew Lock       Andrewlock            1100            38849
# 3  10788822   Tim Thompson  yourinsaneworld            6497             5902
# 4  14596967        fxgenie          fxgenie            3203             2570
#
#    friends_count  favourites_count  listed_count  \
# 0           1978              3200             9
# 1           3595                 8            22
# 2          34504                41          1014
# 3           5496                 0            82
# 4           2638                 0             5
#
#                                      url      location  default_profile  \
# 0                 http://lifeofearth.org      Berekely              NaN
# 1  http://www.yourinternetbuddies.com/go            UK              NaN
# 2          http://www.helpmybusiness.com  Planet Earth              NaN
# 3       http://investing-information.com   Houston, TX              NaN
# 4              http://www.4xgenie.com/wp           usa              NaN
#
#    default_profile_image  geo_enabled  \
# 0                    NaN          NaN
# 1                    NaN          NaN
# 2                    NaN          NaN
# 3                    NaN          NaN
# 4                    NaN          NaN
#
#                                    profile_image_url profile_banner_url  \
# 0  http://a1.twimg.com/profile_images/53905961/st...                NaN
# 1  http://a3.twimg.com/profile_images/719249843/d...                NaN
# 2  http://a3.twimg.com/profile_images/516987291/b...                NaN
# 3  http://a3.twimg.com/profile_images/200984855/t...                NaN
# 4  http://a2.twimg.com/profile_images/53530606/sh...                NaN
#
#    profile_use_background_image profile_background_image_url_https  \
# 0                           NaN                                NaN
# 1                           NaN                                NaN
# 2                           NaN                                NaN
# 3                           NaN                                NaN
# 4                           NaN                                NaN
#
#   profile_image_url_https                       profile_background_image_url  \
# 0                     NaN  http://s.twimg.com/a/1288374569/images/themes/...
# 1                     NaN  http://a3.twimg.com/profile_background_images/...
# 2                     NaN  http://s.twimg.com/a/1288305442/images/themes/...
# 3                     NaN  http://s.twimg.com/a/1288039940/images/themes/...
# 4                     NaN  http://a1.twimg.com/profile_background_images/...
#
#    verified                                        description  \
# 0       NaN                                     Love Your Life
# 1       NaN  I am an internet marketing coach and mentor wh...
# 2       NaN  Marketing Geek & Presenter of 'Help! My Busine...
# 3       NaN  I am a member of a network of stock investing ...
# 4       NaN                                       forex trader
#
#              timestamp           crawled_at  is_bot
# 0  2007-07-04 14:30:03  2010-11-07 11:10:52       1
# 1  2007-07-26 11:07:31  2010-11-07 11:10:52       1
# 2  2007-10-18 18:36:00  2010-11-07 11:10:52       1
# 3  2007-12-02 17:53:26  2010-11-07 11:10:52       1
# 4  2008-04-30 08:22:14  2010-11-07 11:10:52       1

# %%
traditional_spambots.describe()
# Out:
#                  id  statuses_count  followers_count  friends_count  \
# count  2.631000e+03     2631.000000     2.631000e+03    2631.000000
# mean   4.834289e+08     2365.651083     1.737488e+03     809.709996
# std    9.720966e+08     9902.642794     5.883970e+04    5116.089565
# min    7.248952e+06        0.000000     0.000000e+00       0.000000
# 25%    4.168144e+07        3.000000     9.300000e+01     246.000000
# 50%    7.085288e+07       32.000000     2.790000e+02     383.000000
# 75%    1.050727e+08      225.500000     5.315000e+02     686.500000
# max    4.331280e+09   153689.000000     2.991573e+06  211890.000000
#
#        favourites_count  listed_count  default_profile  default_profile_image  \
# count       2631.000000   2631.000000            107.0                   12.0
# mean           7.971114     31.072216              1.0                    1.0
# std          244.428583    594.861760              0.0                    0.0
# min            0.000000      0.000000              1.0                    1.0
# 25%            0.000000      1.000000              1.0                    1.0
# 50%            0.000000      4.000000              1.0                    1.0
# 75%            0.000000     15.000000              1.0                    1.0
# max        11962.000000  24348.000000              1.0                    1.0
#
#        geo_enabled  profile_use_background_image  verified  is_bot
# count       1106.0                        1513.0       0.0  2631.0
# mean           1.0                           1.0       NaN     1.0
# std            0.0                           0.0       NaN     0.0
# min            1.0                           1.0       NaN     1.0
# 25%            1.0                           1.0       NaN     1.0
# 50%            1.0                           1.0       NaN     1.0
# 75%            1.0                           1.0       NaN     1.0
# max            1.0                           1.0       NaN     1.0

# %%
del real_accounts['is_translator']
del real_accounts['follow_request_sent']
del real_accounts['protected']
del real_accounts['contributors_enabled']
del real_accounts['following']
del real_accounts['notifications']
del real_accounts['profile_link_color']
del real_accounts['profile_background_color']
del real_accounts['profile_sidebar_fill_color']
del real_accounts['profile_sidebar_border_color']
del real_accounts['profile_text_color']
del real_accounts['profile_background_tile']
del real_accounts['updated']
del real_accounts['utc_offset']
del real_accounts['lang']
del real_accounts['time_zone']
del real_accounts['test_set_1']
del real_accounts['test_set_2']
del real_accounts['crawled_at']
del real_accounts['timestamp']

# %%
real_accounts.head()
# Out:
#            id               name      screen_name  statuses_count  \
# 0  1502026416    TASUKU HAYAKAWA         0918Bask            2177
# 1  2492782375              ro_or         1120Roll            2660
# 2   293212315           bearclaw        14KBBrown            1254
# 3   191839658  pocahontas farida      wadespeters          202968
# 4  3020965143           Ms Kathy  191a5bd05da04dc              82
#
#    followers_count  friends_count  favourites_count  listed_count  \
# 0              208            332               265             1
# 1              330            485              3972             5
# 2              166            177              1185             0
# 3             2248            981             60304           101
# 4               21             79                 5             0
#
#                       url                   location  default_profile  \
# 0                     NaN             Tokyo .Japan .              NaN
# 1                     NaN                    神奈川県横浜市              1.0
# 2                     NaN                        NaN              NaN
# 3  http://t.co/rGV0HIJGsu  #freePalestine - rip paul              NaN
# 4                     NaN                 Wichita KS              1.0
#
#    default_profile_image  geo_enabled  \
# 0                    NaN          1.0
# 1                    NaN          1.0
# 2                    NaN          NaN
# 3                    NaN          1.0
# 4                    NaN          NaN
#
#                                    profile_image_url  \
# 0  http://pbs.twimg.com/profile_images/5887331863...
# 1  http://pbs.twimg.com/profile_images/5737442928...
# 2  http://pbs.twimg.com/profile_images/5908597242...
# 3  http://pbs.twimg.com/profile_images/5915979249...
# 4  http://pbs.twimg.com/profile_images/5635511026...
#
#                                   profile_banner_url  \
# 0  https://pbs.twimg.com/profile_banners/15020264...
# 1  https://pbs.twimg.com/profile_banners/24927823...
# 2  https://pbs.twimg.com/profile_banners/29321231...
# 3  https://pbs.twimg.com/profile_banners/19183965...
# 4                                                NaN
#
#    profile_use_background_image  \
# 0                           NaN
# 1                           1.0
# 2                           1.0
# 3                           1.0
# 4                           1.0
#
#                   profile_background_image_url_https  \
# 0  https://abs.twimg.com/images/themes/theme1/bg.png
# 1  https://abs.twimg.com/images/themes/theme1/bg.png
# 2  https://pbs.twimg.com/profile_background_image...
# 3  https://abs.twimg.com/images/themes/theme3/bg.gif
# 4  https://abs.twimg.com/images/themes/theme1/bg.png
#
#                              profile_image_url_https  \
# 0  https://pbs.twimg.com/profile_images/588733186...
# 1  https://pbs.twimg.com/profile_images/573744292...
# 2  https://pbs.twimg.com/profile_images/590859724...
# 3  https://pbs.twimg.com/profile_images/591597924...
# 4  https://pbs.twimg.com/profile_images/563551102...
#
#                         profile_background_image_url  verified  \
# 0   http://abs.twimg.com/images/themes/theme1/bg.png       NaN
# 1   http://abs.twimg.com/images/themes/theme1/bg.png       NaN
# 2  http://pbs.twimg.com/profile_background_images...       NaN
# 3   http://abs.twimg.com/images/themes/theme3/bg.gif       NaN
# 4   http://abs.twimg.com/images/themes/theme1/bg.png       NaN
#
#                                          description  \
# 0                              15years ago X.Lines24
# 1   保守見習い地元大好き人間。 経済学、電工、仏教を勉強中、ちなDeではいかんのか？ (*^◯^*)
# 2                 Let me see what your best move is!
# 3  20. menna: #farida #nyc and the 80s actually y...
# 4                                      Cosmetologist
#
#                        created_at  is_bot
# 0  Tue Jun 11 11:20:35 +0000 2013       0
# 1  Tue May 13 10:37:57 +0000 2014       0
# 2  Wed May 04 23:30:37 +0000 2011       0
# 3  Fri Sep 17 14:02:10 +0000 2010       0
# 4  Fri Feb 06 04:10:49 +0000 2015       0

# %% [markdown]
# Aqui, definimos nosso base de treino, concatenando os dados tratados dos usuários e das contas falsas.

# %%
df_train = pd.concat([traditional_spambots, real_accounts[:(traditional_spambots.shape[0])]],ignore_index=True)
df_train.shape
# Out:
# (5262, 25)

# %%
df_train.dtypes
# Out:
# id                                      int64
# name                                   object
# screen_name                            object
# statuses_count                          int64
# followers_count                         int64
# friends_count                           int64
# favourites_count                        int64
# listed_count                            int64
# url                                    object
# location                               object
# default_profile                       float64
# default_profile_image                 float64
# geo_enabled                           float64
# profile_image_url                      object
# profile_banner_url                     object
# profile_use_background_image          float64
# profile_background_image_url_https     object
# profile_image_url_https                object
# profile_background_image_url           object
# verified                              float64
# description                            object
# timestamp                              object
# crawled_at                             object
# is_bot                                  int64
# created_at                             object
# dtype: object

# %% [markdown]
# Para que não tenhamos dados não tratados, analisaremos quais colunas possuem dados faltantes em seus registros. E dependendo do tipo do dado, faremos o tratamento apropriado.

# %%
df_train.isnull().any()
# Out:
# id                                    False
# name                                   True
# screen_name                           False
# statuses_count                        False
# followers_count                       False
# friends_count                         False
# favourites_count                      False
# listed_count                          False
# url                                    True
# location                               True
# default_profile                        True
# default_profile_image                  True
# geo_enabled                            True
# profile_image_url                     False
# profile_banner_url                     True
# profile_use_background_image           True
# profile_background_image_url_https     True
# profile_image_url_https                True
# profile_background_image_url          False
# verified                               True
# description                            True
# timestamp                              True
# crawled_at                             True
# is_bot                                False
# created_at                             True
# dtype: bool

# %%
df_train['name'].fillna('',inplace=True)
df_train['url'].fillna('',inplace=True)
df_train['location'].fillna('',inplace=True)
df_train['default_profile'].fillna(0.0,inplace=True)
df_train['default_profile_image'].fillna(0.0,inplace=True)
df_train['geo_enabled'].fillna(0.0,inplace=True)
df_train['profile_banner_url'].fillna('',inplace=True)
df_train['profile_use_background_image'].fillna(0.0,inplace=True)
df_train['description'].fillna('',inplace=True)
df_train['created_at'].fillna('',inplace=True)
df_train['verified'].fillna(0.0,inplace=True)

# %% [markdown]
# Note que agora não temos mais registros nulos.

# %%
df_train.isnull().any()
# Out:
# id                                    False
# name                                  False
# screen_name                           False
# statuses_count                        False
# followers_count                       False
# friends_count                         False
# favourites_count                      False
# listed_count                          False
# url                                   False
# location                              False
# default_profile                       False
# default_profile_image                 False
# geo_enabled                           False
# profile_image_url                     False
# profile_banner_url                    False
# profile_use_background_image          False
# profile_background_image_url_https     True
# profile_image_url_https                True
# profile_background_image_url          False
# verified                              False
# description                           False
# timestamp                              True
# crawled_at                             True
# is_bot                                False
# created_at                            False
# dtype: bool

# %% [markdown]
# Checamos os tipos novamente para validar se algum tipo foi alterado indevtidamente.

# %%
df_train.dtypes
# Out:
# id                                      int64
# name                                   object
# screen_name                            object
# statuses_count                          int64
# followers_count                         int64
# friends_count                           int64
# favourites_count                        int64
# listed_count                            int64
# url                                    object
# location                               object
# default_profile                       float64
# default_profile_image                 float64
# geo_enabled                           float64
# profile_image_url                      object
# profile_banner_url                     object
# profile_use_background_image          float64
# profile_background_image_url_https     object
# profile_image_url_https                object
# profile_background_image_url           object
# verified                              float64
# description                            object
# timestamp                              object
# crawled_at                             object
# is_bot                                  int64
# created_at                             object
# dtype: object

# %%
df_train.shape
# Out:
# (5262, 25)

# %% [markdown]
# Para facilitar a extração das informações relevantes dos nossos dados, utilizaremos as seguintes funções:

# %%
def has_description(row):
    if row['description']:
        return 1
    else: 
        return 0

def has_url(row):
    if row['url']:
        return 1
    else:
        return 0

def is_geo_enabled(row):
    if row['geo_enabled']:
        return 1
    else:
        return 0

def has_50_tweets(row):
    if row['statuses_count'] >= 50:
        return 1
    else: 
        return 0

def has_never_tweeted(row):
    if row['statuses_count'] == 0:
        return 1
    else:
        return 0

def has_1000_followers(row):
    if row['followers_count'] >= 1000:
        return 1
    else:
        return 0

def has_30_followers(row):
    if row['followers_count'] >= 30:
        return 1
    else: 
        return 0

def has_50_1_ratio(row):
    if 50*row['followers_count'] >= row['friends_count']:
        return 1
    else:
        return 0

def has_100_1_ratio(row):
    if 100* row['followers_count']>= row['friends_count']:
        return 1
    else: 
        return 0

def has_profile_image(row):
    if row['default_profile_image']:
        return 0
    else:
        return 1

def is_bot(row):
    if row['is_bot']:
        return 1
    else:
        return 0

# %% [markdown]
# Na sequência definimos nossa matriz binária que será montada de acordo com dos dados obtidos e as métricas definidas nas referências citadas no início do notebook

# %%
binary_matrix_train = pd.DataFrame()
binary_matrix_train['has_description'] = df_train.apply(lambda x: has_description(x), axis=1)
binary_matrix_train['has_url'] = df_train.apply(lambda x: has_url(x), axis=1)
binary_matrix_train['is_geo_enabled'] = df_train.apply(lambda x: is_geo_enabled(x), axis=1)
binary_matrix_train['has_profile_image'] = df_train.apply(lambda x: has_profile_image(x), axis=1)
binary_matrix_train['has_100_1_ratio'] = df_train.apply(lambda x: has_100_1_ratio(x), axis=1)
binary_matrix_train['has_50_1_ratio'] = df_train.apply(lambda x: has_50_1_ratio(x), axis=1)
binary_matrix_train['has_30_followers'] = df_train.apply(lambda x: has_30_followers(x), axis=1)
binary_matrix_train['has_never_tweeted'] = df_train.apply(lambda x: has_never_tweeted(x), axis=1)
binary_matrix_train['has_50_tweets'] = df_train.apply(lambda x: has_50_tweets(x), axis=1)
binary_matrix_train['has_1000_followers'] = df_train.apply(lambda x: has_1000_followers(x), axis=1)
binary_matrix_train['is_bot'] = df_train.apply(lambda x: is_bot(x), axis=1)

# %%
binary_matrix_train.shape
# Out:
# (5262, 11)

# %% [markdown]
# Agora separaremos as classificações do restante dos nossos dados. Para obtermos nosso X e Y

# %%
x = binary_matrix_train.iloc[:,:10]
x.head()
# Out:
#    has_description  has_url  is_geo_enabled  has_profile_image  \
# 0                1        1               0                  1
# 1                1        1               0                  1
# 2                1        1               0                  1
# 3                1        1               0                  1
# 4                1        1               0                  1
#
#    has_100_1_ratio  has_50_1_ratio  has_30_followers  has_never_tweeted  \
# 0                1               1                 1                  0
# 1                1               1                 1                  0
# 2                1               1                 1                  0
# 3                1               1                 1                  0
# 4                1               1                 1                  0
#
#    has_50_tweets  has_1000_followers
# 0              1                   0
# 1              1                   1
# 2              1                   1
# 3              1                   1
# 4              1                   1

# %%
y = binary_matrix_train['is_bot']
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: is_bot, dtype: int64

# %% [markdown]
# A partir de x,y obteremos nossos dados para treino e teste. A função utilizada para isso é da biblioteca sklearn. Basicamente, a função train_test_split divide nossos dados de acordo com alguns parâmetros.
#
# O parâmetro random_state setado como zero evita de que obtenhamos novos dados para treino e teste toda vez que o código é executado, evitando assim a inconsistência dos nossos resultados.
#
# test_size define a proporção que utilizaremos para treino/teste, nesse caso, 25% dos dados serão para teste.
#
# Por último, stratify define uma coluna para a estratificação dos nossos dados. Ou seja, para manter proporção entre as amostras de treino e teste.
#
# Imagine que, hipoteticamente tenhamos 90% dos nossos dados sendo da classe bot e 10% da classe de contas genuínas, caso não deixemos nossos dados balenceados podemos acabar tendo pouquíssimos dados da classe de perfis genuínos nos nossos dados de treino, o que pode acabar impactando fortemente no desempenho dos algoritmos de classificação.

# %%
train_x, test_x, train_y, test_y = train_test_split(x,y,random_state=0, test_size = 0.25, stratify = y)
train_y.value_counts()
# Out:
# 1    1973
# 0    1973
# Name: is_bot, dtype: int64

# %%
test_y.value_counts()
# Out:
# 1    658
# 0    658
# Name: is_bot, dtype: int64

# %% [markdown]
# Aqui definimos o nosso baseline a ser batido. O algoritmo utilizado é bem simples, ele apenas classificará baseado na classe que aparece com o maior frequência em nossos dados, ou seja, ele dirá que todos os perfis são genuínos.
#
# É importante definir tal métrica para avaliar se a predição que estamos fazendo é de fato válida ou pode ser ignorada.

# %%
modelDummy = DummyClassifier(strategy="most_frequent")
modelDummy.fit(train_x, train_y)
predictions = modelDummy.predict(test_x)
score = np.around(accuracy_score(test_y, predictions)*100,decimals=2)
print(f'Acurácia do Dummy Classifier(Baseline) chutando apenas a resposta de maior frequência é: {score}%')
# Out:
# Acurácia do Dummy Classifier(Baseline) chutando apenas a resposta de maior frequência é: 50.0%

# %% [markdown]
# Para facilitar o entendimento dos resultados que obteremos posteriomente também utilizaremos a seguinte função para analisar os dados da matriz de confusão:

# %%
def confusion_matrix_description(conf_matrix):    
    plt.figure(figsize= (10,8))
    sns.set(font_scale=2)
    sns.heatmap(conf_matrix, annot=True, fmt="d").set(xlabel="Prediction", ylabel="Real")
    true_negative, false_positive, false_negative, true_positive = conf_matrix.ravel()
    print(f'Verdadeiro Negativo(Diz que não é bot e não é): {true_negative}, {np.around((true_negative/(true_negative+false_positive))*100,decimals=2)}% do total')
    print(f'Falso positivo(Diz que é bot, mas não é): {false_positive}, {np.around((false_positive/(true_negative+false_positive))*100,decimals=2)}% do total')
    print(f'Falso Negativo(Diz que não é bot, mas é ): {false_negative}, {np.around((false_negative/(true_positive+false_negative))*100,decimals=2)}% do total' )
    print(f'Verdadeiro Positivo(Diz que é bot e é ): {true_positive}, {np.around((true_positive/(true_positive+false_negative))*100,decimals=2)}% do total')

# %% [markdown]
# A seguir, utilizaremos diversos algoritmos de próposito geral para avaliação das nossas métricas.

# %%
modelLinear = LinearSVC()
modelLinear.fit(train_x, train_y)
predictions = modelLinear.predict(test_x)
score = np.around(accuracy_score(test_y, predictions)*100,decimals=2)
print(f'Acurácia do modelo LinearSVC é: {score}%')
# Out:
# Acurácia do modelo LinearSVC é: 80.24%

# %%
linear_confusion_matrix = confusion_matrix(test_y, predictions)
linear_confusion_matrix
# Out:
# array([[587,  71],
#        [189, 469]], dtype=int64)

# %% [markdown]
# Ao analisar a matriz de confusão do modelo LinearSVC, temos os seguintes resultados:

# %%
confusion_matrix_description(linear_confusion_matrix)
# Out:
# Verdadeiro Negativo(Diz que não é bot e não é): 587, 89.21% do total
# Falso positivo(Diz que é bot, mas não é): 71, 10.79% do total
# Falso Negativo(Diz que não é bot, mas é ): 189, 28.72% do total
# Verdadeiro Positivo(Diz que é bot e é ): 469, 71.28% do total

# %%
modelNB = MultinomialNB()
modelNB.fit(train_x, train_y)
predictions = modelNB.predict(test_x)
score = np.around(accuracy_score(test_y, predictions)*100,decimals=2)
print(f'Acurácia do modelo Multinomial de Naive Bayes é: {score}%')
# Out:
# Acurácia do modelo Multinomial de Naive Bayes é: 78.42%

# %%
nb_confusion_matrix = confusion_matrix(test_y, predictions)
nb_confusion_matrix
# Out:
# array([[488, 170],
#        [114, 544]], dtype=int64)

# %%
confusion_matrix_description(nb_confusion_matrix)
# Out:
# Verdadeiro Negativo(Diz que não é bot e não é): 488, 74.16% do total
# Falso positivo(Diz que é bot, mas não é): 170, 25.84% do total
# Falso Negativo(Diz que não é bot, mas é ): 114, 17.33% do total
# Verdadeiro Positivo(Diz que é bot e é ): 544, 82.67% do total

# %%
modelDecisionTree = DecisionTreeClassifier()
modelDecisionTree.fit(train_x, train_y)
predictions = modelDecisionTree.predict(test_x)
score = np.around(accuracy_score(test_y, predictions)*100,decimals=2)
print(f'Acurácia da árvore de decisão é: {score}%')
# Out:
# Acurácia da árvore de decisão é: 81.99%

# %%
dt_confusion_matrix = confusion_matrix(test_y, predictions)
dt_confusion_matrix
# Out:
# array([[472, 186],
#        [ 51, 607]], dtype=int64)

# %%
confusion_matrix_description(dt_confusion_matrix)
# Out:
# Verdadeiro Negativo(Diz que não é bot e não é): 472, 71.73% do total
# Falso positivo(Diz que é bot, mas não é): 186, 28.27% do total
# Falso Negativo(Diz que não é bot, mas é ): 51, 7.75% do total
# Verdadeiro Positivo(Diz que é bot e é ): 607, 92.25% do total

# %%
dot_data = export_graphviz(modelDecisionTree,out_file =None, feature_names=x.columns, filled=True, rounded=True)
graph = graphviz.Source(dot_data)
graph

# %%
tsne = TSNE(n_components = 2)
tsne_dimensions = tsne.fit_transform(binary_matrix_train)
plt.figure(figsize=(14,8))
sns.scatterplot(x = tsne_dimensions[:,0] ,y = tsne_dimensions[:,1], hue = binary_matrix_train['is_bot'])
# Out:
# <AxesSubplot:>
